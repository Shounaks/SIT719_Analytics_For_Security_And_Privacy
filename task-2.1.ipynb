# %% [markdown]
# ### Task 2.1 - Basic Scripting with Python
# #### Author: Shounak Bhalerao

# %%
import pandas as pd
import numpy as np
from PIL.ImageColor import colormap

# Answer 1 & 2 do not require Submission

# %%
# Step 2 Code
# url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# iris = pd.read_csv(url)
# iris.head()

# %% [markdown]
# #### Step #3: Write code to create 5 column heads. Next write a code to display or show the headers.

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris = pd.read_csv(url, names=['sepal_length','sepal_width','petal_length','petal_width','class'])
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# #### Step #4: Write a code to check if there are any missing values in the dataframe

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %% [markdown]
# Step 5: Write a code to set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
# iris[10:30]['petal_length'] = 'NaN' <- This will not work :)
iris.loc[10:29,'petal_length'] = np.nan
iris.head(31)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           NaN          0.2  Iris-setosa
# 11           4.8          3.4           NaN          0.2  Iris-setosa
# ...

# %% [markdown]
# Step 6. Now again, check if there is any missing values (NaN) in the dataframe? Count, how many missing values.

# %%
iris.isnull().sum()
# Out:
# sepal_length     0
# sepal_width      0
# petal_length    20
# petal_width      0
# class            0
# dtype: int64

# %% [markdown]
# Step 7. Substitute the NaN values to 10.0
#
# This can be done with iris.loc(10:29,'petal_length') = 10.0 but the problem with this is that it will not remove all the NAN items. hence lets do it using methods which will fix the WHOLE Dataset

# %%
iris['petal_length'].fillna(10.0, inplace=True)
iris.head(30)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7          10.0          0.2  Iris-setosa
# 11           4.8          3.4          10.0          0.2  Iris-setosa
# ...

# %%
iris['sepal_length'].plot(kind='hist', edgecolor="black", xlabel='Sepal Lenght (mm)', title='Sepal Lenght from Iris dataset', grid=False)
# Out:
# <Axes: title={'center': 'Sepal Lenght from Iris dataset'}, xlabel='Sepal Lenght (mm)', ylabel='Frequency'>

# %%
iris['class'].value_counts()#.plot(kind='bar', edgecolor="black",ylabel='Count', title='Class Counts', grid=False)
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: class, Length: 150, dtype: object
