# %%
import pandas as pd
from pandas import DataFrame
from sklearn.model_selection import StratifiedShuffleSplit

df: DataFrame = pd.read_csv('data/Week_5_NSL-KDD-Dataset/kdd_merged.csv')
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
strat_train_set = set()
strat_test_set = set()
for train_index, test_index in split.split(df, df["attack_category"]):
     strat_train_set = df.loc[train_index]
     strat_test_set = df.loc[test_index]
# Out:
#         duration protocol_type  service flag  src_bytes  dst_bytes  land  \
# 50312          0           tcp     http   SF        229       1797     0
# 135011         0           tcp  private  REJ          0          0     0
# 57898          0           tcp     http   SF        311       4134     0
# 114376         0           udp  private   SF          1          0     0
# 39719          0           tcp  courier   S0          0          0     0
# ...          ...           ...      ...  ...        ...        ...   ...
# 126153         0          icmp    ecr_i   SF        508          0     0
# 113610         0           tcp     smtp   SF       1714        327     0
# 130465         0           tcp     http   SF        208        753     0
# 82432          0           tcp     http   SF        317       1548     0
# 147709      7650           tcp   telnet   SF          0         44     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_diff_srv_rate  \
# 50312                0       0    0  ...                    0.00
# 135011               0       0    0  ...                    0.06
# 57898                0       0    0  ...                    0.00
# 114376               0       0    0  ...                    0.24
# 39719                0       0    0  ...                    0.07
# ...                ...     ...  ...  ...                     ...
# 126153               0       0    0  ...                    0.00
# 113610               0       0    0  ...                    0.03
# 130465               0       0    0  ...                    0.00
# 82432                0       0    0  ...                    0.00
# 147709               0       0    0  ...                    0.02
#
#         dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 50312                          0.00                         0.00
# 135011                         0.00                         0.00
# 57898                          0.02                         0.01
# 114376                         1.00                         0.00
# 39719                          0.00                         0.00
# ...                             ...                          ...
# 126153                         1.00                         0.00
# 113610                         0.01                         0.02
# 130465                         0.00                         0.01
# 82432                          0.10                         0.04
# 147709                         0.00                         0.00
#
#         dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 50312                   0.00                      0.00                  0.00
# 135011                  0.00                      0.00                  1.00
# 57898                   0.00                      0.00                  0.00
# 114376                  0.00                      0.00                  0.00
# 39719                   1.00                      1.00                  0.00
# ...                      ...                       ...                   ...
# 126153                  0.00                      0.00                  0.00
# 113610                  0.02                      0.02                  0.00
# 130465                  0.00                      0.00                  0.00
# 82432                   0.00                      0.00                  0.00
# 147709                  0.50                      0.48                  0.01
#
#         dst_host_srv_rerror_rate   attack_type  success_pred  attack_category
# 50312                       0.00        normal            21           benign
# 135011                      1.00       neptune            21              dos
# 57898                       0.00        normal            21           benign
# 114376                      0.00         satan            15            probe
# 39719                       0.00       neptune            19              dos
# ...                          ...           ...           ...              ...
# 126153                      0.00         smurf            18              dos
# 113610                      0.00        normal            21           benign
# 130465                      0.00        normal            21           benign
# 82432                       0.00        normal            21           benign
# 147709                      0.01  processtable            18              dos
#
# [118813 rows x 44 columns]
